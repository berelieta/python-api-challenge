# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
# Import API key
from config import api_key

# Import citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../WeatherPy/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# # CODE: Generate cities

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %% [markdown]
# # API Weather

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"

column_names = ["City","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Country","Date"]
results = []

def k_to_f(k):
    return 9 / 5 * (k - 273) + 32

print("""Beginning Data Retrieval-----------------------------""")


# Build query URL
for index, city in enumerate(cities, start=1):
    print(f'Processing Record {index} of {len(cities)} | {city}')
    city_data = []
    # Build query URL
    query_url = url + "appid=" + api_key + "&q=" + city
    
    weather_response = requests.get(query_url, city).json()
    
    if weather_response.get("cod") and weather_response.get("cod") == '404':
        print(f'{city} not found. Skipping...')
        continue
    
    try:
        city_data.append(city)                                           # Append City name 
        city_data.append(weather_response["coord"]["lat"])               # Append City Lat
        city_data.append(weather_response["coord"]["lon"])               # Append City Long
        city_data.append(k_to_f(weather_response["main"]["temp_max"]))   # Append Max Temp
        city_data.append(weather_response["main"]["humidity"])           # Append Hummidity
        city_data.append(weather_response["clouds"]["all"])   # Append Cloudiness
        city_data.append(weather_response["wind"]["speed"])              # Append Wind Speed
        city_data.append(weather_response["sys"]["country"])             # Append Country
        city_data.append(weather_response["dt"])                         # Append Date
        # Append city data to full data
        results.append(city_data)
        
    except:
        print(f'Unexpected issue with {city}: {weather_response}')
# Out:
# Beginning Data Retrieval-----------------------------
# Processing Record 1 of 605 | albany
# Processing Record 2 of 605 | hofn
# Processing Record 3 of 605 | ranau
# Processing Record 4 of 605 | sao filipe
# Processing Record 5 of 605 | olafsvik
# Processing Record 6 of 605 | lambarene
# Processing Record 7 of 605 | san anselmo
# Processing Record 8 of 605 | mar del plata
# Processing Record 9 of 605 | port elizabeth
# Processing Record 10 of 605 | port alfred
# Processing Record 11 of 605 | cidreira
# Processing Record 12 of 605 | marcona
# marcona not found. Skipping...
# Processing Record 13 of 605 | tiksi
# Processing Record 14 of 605 | rio grande
# Processing Record 15 of 605 | tsihombe
# tsihombe not found. Skipping...
# Processing Record 16 of 605 | chuy
# Processing Record 17 of 605 | bezenchuk
# Processing Record 18 of 605 | kruisfontein
# Processing Record 19 of 605 | road town
# Processing Record 20 of 605 | luderitz
# Processing Record 21 of 605 | saint-pierre
# Processing Record 22 of 605 | kavieng
# Processing Record 23 of 605 | guerrero negro
# Processing Record 24 of 605 | arraial do cabo
# Processing Record 25 of 605 | atuona
# Processing Record 26 of 605 | antofagasta
# Processing Record 27 of 605 | baniachang
# Processing Record 28 of 605 | hithadhoo
# Processing Record 29 of 605 | samusu
# samusu not found. Skipping...
# Processing Record 30 of 605 | rawannawi
# rawannawi not found. Skipping...
# Processing Record 31 of 605 | khatanga
# Processing Record 32 of 605 | talnakh
# Processing Record 33 of 605 | saint-augustin
# Processing Record 34 of 605 | kapit
# Processing Record 35 of 605 | bluff
# Processing Record 36 of 605 | puerto ayora
# Processing Record 37 of 605 | bathsheba
# Processing Record 38 of 605 | hami
# Processing Record 563 of 605 | grand centre
# grand centre not found. Skipping...
# Processing Record 564 of 605 | beringovskiy
# Processing Record 565 of 605 | saint-joseph
# Processing Record 566 of 605 | tanggu
# Processing Record 567 of 605 | port hardy
# Processing Record 568 of 605 | dubovskoye
# Processing Record 569 of 605 | salima
# Processing Record 570 of 605 | abong mbang
# Processing Record 571 of 605 | port shepstone
# Processing Record 572 of 605 | dzhusaly
# dzhusaly not found. Skipping...
# Processing Record 573 of 605 | tomelloso
# Processing Record 574 of 605 | cagayan de tawi-tawi
# cagayan de tawi-tawi not found. Skipping...
# Processing Record 575 of 605 | tateyama
# Processing Record 576 of 605 | ucluelet
# Processing Record 577 of 605 | wadi maliz
# Processing Record 578 of 605 | northam
# Processing Record 579 of 605 | leh
# Processing Record 580 of 605 | ahuimanu
# Processing Record 581 of 605 | pinsk
# Processing Record 582 of 605 | dumas
# Processing Record 583 of 605 | itarema
# Processing Record 584 of 605 | kangundo
# Processing Record 585 of 605 | queanbeyan
# Processing Record 586 of 605 | tupiza
# Processing Record 587 of 605 | sitka
# Processing Record 588 of 605 | mananjary
# Processing Record 589 of 605 | provost
# Processing Record 590 of 605 | comodoro rivadavia
# Processing Record 591 of 605 | miandrivazo
# Processing Record 592 of 605 | mineros
# Processing Record 593 of 605 | fenoarivo
# Processing Record 594 of 605 | taoudenni
# Processing Record 595 of 605 | nasturelu
# Processing Record 596 of 605 | axim
# Processing Record 597 of 605 | yerofey pavlovich
# Processing Record 598 of 605 | atar
# Processing Record 599 of 605 | beyneu
# Processing Record 600 of 605 | lagunas
# Processing Record 601 of 605 | peleduy
# Processing Record 602 of 605 | bajil
# Processing Record 603 of 605 | harlingen
# Processing Record 604 of 605 | tommot
# Processing Record 605 of 605 | cherepovets

# %%
# Converting to dataframe 
df = pd.DataFrame(results, columns=column_names)

# %%
# Export into csv 
df.to_csv(output_data_file, index=False)

# show dataframe 
df
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         albany  42.60  -73.97    80.276        53           0        2.00
# 1           hofn  64.25  -15.21    53.870        87          90        7.70
# 2          ranau   5.95  116.66    79.070        83          20        2.10
# 3     sao filipe  14.90  -24.50    76.100        77          41        4.80
# 4       olafsvik  64.89  -23.71    51.800        88         100        8.95
# ..           ...    ...     ...       ...       ...         ...         ...
# 548      peleduy  59.63  112.74    62.222        73          84        4.05
# 549        bajil  15.06   43.29    80.690        81         100        3.38
# 550    harlingen  26.19  -97.70    89.276        79          75        6.70
# 551       tommot  58.96  126.29    58.154        83         100        1.93
# 552  cherepovets  59.13   37.90    57.470       100          90        2.00
#
#     Country        Date
# 0        US  1596209588
# 1        IS  1596209707
# 2        MY  1596209708
# 3        CV  1596209708
# 4        IS  1596209709
# ..      ...         ...
# 548      RU  1596209936
# 549      YE  1596209936
# 550      US  1596209936
# 551      RU  1596209937
# 552      RU  1596209937
#
# [553 rows x 9 columns]

# %%
drop_rows = df.loc[df['Humidity'] > 100].index

# Delete these row indexes from dataFrame
cleaned = df.drop(drop_rows, inplace=False)

# # Showing df after dropping rows 
cleaned
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         albany  42.60  -73.97    80.276        53           0        2.00
# 1           hofn  64.25  -15.21    53.870        87          90        7.70
# 2          ranau   5.95  116.66    79.070        83          20        2.10
# 3     sao filipe  14.90  -24.50    76.100        77          41        4.80
# 4       olafsvik  64.89  -23.71    51.800        88         100        8.95
# ..           ...    ...     ...       ...       ...         ...         ...
# 548      peleduy  59.63  112.74    62.222        73          84        4.05
# 549        bajil  15.06   43.29    80.690        81         100        3.38
# 550    harlingen  26.19  -97.70    89.276        79          75        6.70
# 551       tommot  58.96  126.29    58.154        83         100        1.93
# 552  cherepovets  59.13   37.90    57.470       100          90        2.00
#
#     Country        Date
# 0        US  1596209588
# 1        IS  1596209707
# 2        MY  1596209708
# 3        CV  1596209708
# 4        IS  1596209709
# ..      ...         ...
# 548      RU  1596209936
# 549      YE  1596209936
# 550      US  1596209936
# 551      RU  1596209937
# 552      RU  1596209937
#
# [553 rows x 9 columns]

# %% [markdown]
# # Plotting: latitude vs. temperature

# %%
lat_temp = cleaned.loc[:,['Lat', 'Max Temp']]

x= lat_temp['Lat']; y = lat_temp['Max Temp'];
plt.scatter(x,y)
plt.title("Latitude vs Temperature Plot")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.show()

# %% [markdown]
# # Plotting: latitude vs. humidity

# %%
lat_hum = cleaned.loc[:,['Lat', 'Humidity']]

x= lat_hum['Lat']; y = lat_hum['Humidity'];
plt.scatter(x,y)
plt.title("Latitude vs Humidity Plot")
plt.xlabel("Latitude")
plt.ylabel("Humidity ")
plt.show()

# %% [markdown]
# # Plotting: latitude vs. cloudiness

# %%
lat_clo = cleaned.loc[:,['Lat', 'Cloudiness']]

x= lat_clo['Lat']; y = lat_clo['Cloudiness'];
plt.scatter(x,y)
plt.title("Latitude vs Cloudiness Plot")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.show()

# %% [markdown]
# # Plotting: latitude vs. wind speed

# %%
lat_win = cleaned.loc[:,['Lat', 'Wind Speed']]

x= lat_win['Lat']; y = lat_win['Wind Speed'];
plt.scatter(x,y)
plt.title("Latitude vs Wind Speed Plot")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.show()

# %% [markdown]
# # Create Northern and Southern Hemisphere DataFrames

# %%
# Northern Hemisphere DataFrames
northern_hem = cleaned.loc[cleaned['Lat'] >= 0]

# Show dataframe 
northern_hem
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         albany  42.60  -73.97    80.276        53           0        2.00
# 1           hofn  64.25  -15.21    53.870        87          90        7.70
# 2          ranau   5.95  116.66    79.070        83          20        2.10
# 3     sao filipe  14.90  -24.50    76.100        77          41        4.80
# 4       olafsvik  64.89  -23.71    51.800        88         100        8.95
# ..           ...    ...     ...       ...       ...         ...         ...
# 548      peleduy  59.63  112.74    62.222        73          84        4.05
# 549        bajil  15.06   43.29    80.690        81         100        3.38
# 550    harlingen  26.19  -97.70    89.276        79          75        6.70
# 551       tommot  58.96  126.29    58.154        83         100        1.93
# 552  cherepovets  59.13   37.90    57.470       100          90        2.00
#
#     Country        Date
# 0        US  1596209588
# 1        IS  1596209707
# 2        MY  1596209708
# 3        CV  1596209708
# 4        IS  1596209709
# ..      ...         ...
# 548      RU  1596209936
# 549      YE  1596209936
# 550      US  1596209936
# 551      RU  1596209937
# 552      RU  1596209937
#
# [361 rows x 9 columns]

# %%
# Southern Hemisphere DataFrames

southern_hem = cleaned.loc[cleaned['Lat'] <= 0]

#show dataframe 
southern_hem
# Out:
#                    City    Lat    Lng  Max Temp  Humidity  Cloudiness  \
# 5             lambarene  -0.70  10.24    85.280        56          34
# 7         mar del plata -38.00 -57.56    49.262        81         100
# 8        port elizabeth -33.92  25.57    62.870        72           0
# 9           port alfred -33.59  26.89    60.566        69           0
# 10             cidreira -30.18 -50.21    62.096        68           0
# ..                  ...    ...    ...       ...       ...         ...
# 537  comodoro rivadavia -45.87 -67.50    52.070        53          42
# 538         miandrivazo -19.52  45.47    79.376        45           0
# 539             mineros -17.12 -63.23    77.270        38          20
# 540           fenoarivo -18.93  47.44    62.870        82          75
# 547             lagunas  -5.23 -75.68    83.984        72          20
#
#      Wind Speed Country        Date
# 5          2.83      GA  1596209709
# 7          5.70      AR  1596209429
# 8          3.10      ZA  1596209710
# 9          1.51      ZA  1596209711
# 10         5.76      BR  1596209711
# ..          ...     ...         ...
# 537        4.10      AR  1596209931
# 538        2.31      MG  1596209932
# 539        1.00      BO  1596209932
# 540        6.70      MG  1596209932
# 547        2.31      PE  1596209935
#
# [192 rows x 9 columns]

# %% [markdown]
# # Linear regression on Northern Hemisphere

# %%
def len_regression(df, x_index, y_index):
    x_np_array = df.iloc[:, x_index].values
    y_np_array = df.iloc[:, y_index].values
    
    x = x_np_array.reshape(-1, 1)
    y = y_np_array.reshape(-1, 1)
    
    linear_regressor = LinearRegression() 
    linear_regressor.fit(x, y)
    y_pred = linear_regressor.predict(x)
    
    plt.xlabel(df.columns[x_index])
    plt.ylabel(df.columns[y_index])
    plt.scatter(x, y)
    plt.plot(x, y_pred, color='red')
    plt.show() 
    # calculating r-squared and printing it 
    r_sq = r2_score(y, y_pred)
    print(f' The r-squared is: {r_sq}')

#calling function 
len_regression(northern_hem, 1, 3)
# Out:
#  The r-squared is: 0.4811294749216528

# %% [markdown]
# # Linear regression on Southern Hemisphere

# %%
len_regression(southern_hem, 1, 3)
# Out:
#  The r-squared is: 0.5846400569391348

# %% [markdown]
# # Northern Hemisphere

# %%
len_regression(northern_hem,1,4)
# Out:
#  The r-squared is: 0.013797581425621375

# %% [markdown]
# # Southern Hemisphere

# %%
len_regression(southern_hem,1,4)
# Out:
#  The r-squared is: 0.019731820148259138

# %% [markdown]
# # Northern Hemisphere

# %%
len_regression(northern_hem,1,5)
# Out:
#  The r-squared is: 0.00018883783087975115

# %% [markdown]
# # Southern Hemisphere

# %%
len_regression(southern_hem,1,5)
# Out:
#  The r-squared is: 0.0020035020965047945

# %% [markdown]
# # Northern Hemisphere

# %%
len_regression(northern_hem,1,6)
# Out:
#  The r-squared is: 0.003607417470316232

# %% [markdown]
# # Southern Hemisphere

# %%
len_regression(southern_hem,1,6)
# Out:
#  The r-squared is: 0.00819091748616152
